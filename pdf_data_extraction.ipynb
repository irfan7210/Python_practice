# %% [markdown]
# <a href="https://colab.research.google.com/github/irfan7210/Python_practice/blob/main/pdf_data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pdf Data Extraction**

# %% [markdown]
# **Using PAndas**

# %%
pip install PyPDF2 pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import re
import os
import csv
import pandas as pd
from PyPDF2 import PdfReader

# %%
import re
import pandas as pd
from PyPDF2 import PdfReader

def Extract_pdf_regex(path):
    name_pattern = r"Name:\s*(.*?)\n"
    ssn_pattern = r"SSN:\s*(.*?)\n"
    pan_pattern = r"PAN:\s*(.*?)\n"

    # Initialize lists
    Names = []
    SSNs = []
    PANs = []

    # Read the PDF
    pdf_reader = PdfReader(path)
    pdf_text = ""

    for page in pdf_reader.pages:
        pdf_text += page.extract_text() + "\n"  # Extract text from each page

    # Apply regex
    Names.extend(re.findall(name_pattern, pdf_text))
    SSNs.extend(re.findall(ssn_pattern, pdf_text))
    PANs.extend(re.findall(pan_pattern, pdf_text))

    # Create DataFrame
    df = pd.DataFrame({"Name": Names, "SSN": SSNs, "PAN": PANs})

    # Save to CSV
    df.to_csv('output.csv', index=False)

# Usage
pdf_path = "/content/sample1.pdf"
Extract_pdf_regex(pdf_path)

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 33.7 MB/s eta 0:00:00
# ...

# %%
import re
import pandas as pd
import fitz  # PyMuPDF

def Extract_pdf_regex(path):
    name_pattern = r"Name:\s*(.*?)\n"
    ssn_pattern = r"SSN:\s*(.*?)\n"
    pan_pattern = r"PAN:\s*(.*?)\n"
    address_pattern = r"Address:\s*(.*?)\n"

    Names = []
    SSNs = []
    PANs = []
    Addresses = []

    pdf_document = fitz.open(path)
    pdf_text = ""
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pdf_text += page.get_text()

    Names.extend(re.findall(name_pattern, pdf_text))
    SSNs.extend(re.findall(ssn_pattern, pdf_text))
    PANs.extend(re.findall(pan_pattern, pdf_text))
    Addresses.extend(re.findall(address_pattern, pdf_text))

    df = pd.DataFrame({"Name": Names,
                       "SSN": SSNs,
                       "PAN": PANs,
                       "Address": Addresses})

    df.to_csv('output.csv', index=False)

pdf_path = "/content/sample1.pdf"
Extract_pdf_regex(pdf_path)

# %%
data = pd.read_csv('output.csv')
data.head()
# Out:
#              Name          SSN          PAN  \
# 0  Mohammad Irfan  123-44-2345  AFTPI385557
# 1    Priya Sharma  321-55-6789   BKTPR7890K
# 2    Rakesh Kumar  234-66-7890   CDEKR1234M
# 3     Sneha Patel  345-77-8901   FGHRP5678N
# 4      Anil Singh  456-88-9012   HJKSN9012P
#
#                                             Address
# 0          701 new colony, gurugaon, haryana 201308
# 1      123 Maple Street, Mumbai, Maharashtra 400001
# 2        456 Oak Avenue, Chennai, Tamil Nadu 600002
# 3        789 Pine Road, Kolkata, West Bengal 700003
# 4  101 Cedar Boulevard, Bengaluru, Karnataka 560004

# %%
import pandas as pd
import numpy as np
import re
import PyPDF2
from PyPDF2 import PdfFileReader

# %%
def Extract_pdf(file_path):
      name_pattern = r"Name:\s*(.*?)\n"
      ssn_pattern = r"SSN:\s*(.*?)\n"
      pan_pattern = r"PAN:\s*(.*?)\n"
      address_pattern = r"Address:\s*(.*?)\n"

      Names = []
      SSNS = []
      PANS = []
      Addresses = []

      with open(file_path, 'rb') as Pdf_files:
        pdf_read = PyPDF2.PdfReader(Pdf_files)
        pdf_data = ""
        for page_num in range(len(pdf_read.pages)):
          pages = pdf_read.pages[page_num]
          pdf_data += pages.extract_text()

      Names.extend(re.findall(name_pattern, pdf_data))
      SSNS.extend(re.findall(ssn_pattern, pdf_data))
      PANS.extend(re.findall(pan_pattern, pdf_data))
      Addresses.extend(re.findall(address_pattern, pdf_data))
      print(pdf_data)
      df = pd.DataFrame({"Name": Names,
                          "SSN": SSNS,
                          "PAN": PANS,
                          "Address": Addresses})

      df.to_csv('output.csv', index=False)

file_path = "/content/sample1.pdf"
Extract_pdf(file_path)
# Out:
# Name:
# Mohammad
# Irfan
# SSN:
# 123-44-2345
# PAN:
# AFTPI385557
# Address:
# 701
# new
# colony,
# gurugaon,
# haryana
# 201308
# Len
# dec
# are
# you
# hppy
# sev
# Here
# are
# 10
# sample
# entries
# similar
# to
# the
# one
# you
# provided:
# 1.
# Name:
# Priya
# Sharma
# SSN:
# 321-55-6789
# PAN:
# BKTPR7890K
# Address:
# 123
# Maple
# Street,
# Mumbai,
# Maharashtra
# 400001
# ill
# extract
# text
# from
# pdf
# files
# using
# two
# Python
# libraries,
# pypdf
# and
# PyMuPDF ,
# in
# this
# article.
# Extracting
# text
# from
# a
# PDF
# file
# using
# th
# 2.
# Name:
# Rakesh
# Kumar
# SSN:
# 234-66-7890
# PAN:
# CDEKR1234M
# Address:
# 456
# Oak
# Avenue,
# Chennai,
# Tamil
# Nadu
# 600002
# ill
# extract
# text
# from
# pdf
# files
# using
# two
# Python
# libraries,
# pypdf
# and
# PyMuPDF ,
# in
# this
# article.
# Extracting
# text
# from
# a
# PDF
# file
# using
# th
# 3.
# Name:
# Sneha
# Patel
# SSN:
# 345-77-8901
# PAN:
# FGHRP5678N
# Address:
# 789
# Pine
# ...

# %%
df = pd.read_csv('/content/output.csv')
df.head()
# Out:
#        Name          SSN          PAN  Address
# 0  Mohammad  123-44-2345  AFTPI385557      701
# 1     Priya  321-55-6789   BKTPR7890K      123
# 2    Rakesh  234-66-7890   CDEKR1234M      456
# 3     Sneha  345-77-8901   FGHRP5678N      789
# 4      Anil  456-88-9012   HJKSN9012P      101

# %% [markdown]
# # **Web Scrapping**

# %% [markdown]
# # using beautiful Soup- test example

# %%
pip install beautifulsoup4

# %%
pip install requests

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# url = "https://webscraper.io/test-sites/e-commerce/allinone"
# r = requests.get(url)
# print(r)

# %%
soup = BeautifulSoup(r.text, "lxml")
#print(soup)
# box = soup.findAll("div", "col-md-4 col-xl-4 col-lg-4")
# print(box)

names = soup.findAll("a", class_ = "title")
#print(names)
for i in names:
  print(i)

prices = soup.findAll("h4", "price float-end card-title pull-right")
for i in prices:
  print(i)
# Out:
# <a class="title" href="/test-sites/e-commerce/allinone/product/58" title="Asus ROG Strix GL702ZC-GC209T">Asus ROG Strix...</a>
# <a class="title" href="/test-sites/e-commerce/allinone/product/42" title="HP 250 G3">HP 250 G3</a>
# <a class="title" href="/test-sites/e-commerce/allinone/product/98" title="Asus ROG Strix GL553VD-DM535T">Asus ROG Strix...</a>
# <h4 class="price float-end card-title pull-right">$1769</h4>
# <h4 class="price float-end card-title pull-right">$520.99</h4>
# <h4 class="price float-end card-title pull-right">$1101.83</h4>

# %% [markdown]
# **TATA IPL**

# %%
url2 = "https://www.iplt20.com/auction/2022"
r = requests.get(url2)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, "lxml")
table = soup.find("table", class_ = "ih-td-tab auction-tbl")
title = table.find_all("th")

#print(title)
header = []
for i in title:
  name = i.text
  header.append(name)
#print(header)
# for i in table:
#   print(i)

df = pd.DataFrame(columns = header)

row = table.find_all("tr")

for j in row[1:]:
  data = j.find_all("td")
  #print(data)

  rows = [tr.text.strip() for tr in data ]
  #print(rows)
  length = len(df)
  # print(length)
  df.loc[length] = rows
print(df)

df.to_csv('ipl.csv')
# Out:
#                           TEAM FUNDS REMAINING OVERSEAS PLAYERS  TOTAL PLAYERS
# 0          Chennai Super Kings    ₹2,95,00,000                 8            25
# 1               Delhi Capitals      ₹10,00,000                 7            24
# 2               Gujarat Titans      ₹15,00,000                 8            23
# 3        Kolkata Knight Riders      ₹45,00,000                 8            25
# 4         Lucknow Super Giants              ₹0                 7            21
# 5               Mumbai Indians      ₹10,00,000                 8            25
# 6                 Punjab Kings    ₹3,45,00,000                 7            25
# 7             Rajasthan Royals      ₹95,00,000                 8            24
# 8  Royal Challengers Bangalore    ₹1,55,00,000                 8            22
# 9          Sunrisers Hyderabad      ₹10,00,000                 8            23

# %% [markdown]
# # **Excel Data Extraction**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import os
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Define the path to the folder in your Google Drive
filepath = '/content/drive/MyDrive/testdat'

# List files in the directory
if os.path.exists(filepath):
    list_of_files = os.listdir(filepath)
    print(list_of_files)
else:
    print(f"Error: The specified folder path '{filepath}' does not exist. Please ensure the folder is shared with you and the path is correct.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['sample data']

# %%
from google.colab import drive
import os
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Define the path to the folder in your Google Drive
filepath = '/content/drive/MyDrive/testdat'

# Check if the directory exists
if os.path.exists(filepath):
    list_of_files = os.listdir(filepath)
    print(f"Files in folder '{filepath}':")
    for file in list_of_files:
        print(f"- {file}")
        file_path = os.path.join(filepath, file) # Create the full file path
        if file.endswith(".txt"):  # Example for .txt files
          try:
            with open(file_path, 'r') as f:
                content = f.read()
                print("Content:")
                print(content)
          except Exception as e:
                print(f"Error reading file: {e}")
        elif file.endswith(".csv"): # Example for .csv files
            try:
                df = pd.read_csv(file_path)
                print("Dataframe:")
                print(df.head())
            except Exception as e:
                print(f"Error reading file: {e}")
        else:
          print("File type not supported for preview")
else:
    print(f"Error: The specified folder path '{filepath}' does not exist. Please ensure the folder is shared with you and the path is correct.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files in folder '/content/drive/MyDrive/testdat':
# - sample data
# File type not supported for preview

# %%
xl_files = [file for file in list_of_files if file.endswith('.csv')]
xl_files
# Out:
# []
